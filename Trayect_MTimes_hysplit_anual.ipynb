# %% [markdown]
# # Corriendo Varias Trayectorias HYSPLIT en ARGOS para diferentes tiempos
#
# Se presentan los pasos para ejecutar HYSPLIT empleando la interfase de Jupyter para trayectorias.
#
# 1. Crear y ubicarse en el directorio de trabajo
# 1. Crear el archivo ASCDATA.CFG
# 1. Configurar los parametros de la ejecución de trayectoria
# 1. Crear el archivo CONTROL
# 1. Ejecutar el programa de trayectorias
# 1. Crear el despliegue

# %%
# %%bash -l
# # para cada mes
# declare -a cmes=(ene feb mar abr may jun jul ago sep oct nov dic)
# for i in ${!cmes[@]}
# do
# # en la variable DIR definir el nombre del directorio
# DIR=${cmes[$i]}
# ims=$(($i+1))
# if [ $ims -lt 10 ]; then ims=0$ims;fi
# # se revisa si existe en el directorio $HOME si no se crea
#
# if [ ! -d ${HOME}/data/$DIR ];then mkdir $HOME/data/$DIR ;fi
#
# # se ubica en el directorio
# cd ${HOME}/data/${DIR}
# #-------------------------------------------------------------
# # set default directory structure if not passed through
#
#   MDL="${HOME}/data/hysplit.v5.2.0_CentOS7.9.2009"
#   OUT="${HOME}/data/${DIR}"
#   MET="${HOME}/data/hysplit_data"
#   cd $OUT
#
#   if [ ! -f ASCDATA.CFG ]; then
#      echo "-90.0  -180.0"     >ASCDATA.CFG
#      echo "0.1     0.1"      >>ASCDATA.CFG
#      echo "1800   3600"      >>ASCDATA.CFG
#      echo "2"                >>ASCDATA.CFG
#      echo "0.2"              >>ASCDATA.CFG
#      echo "'$MDL/bdyfiles/bdyfiles0p1/'" >>ASCDATA.CFG
#   fi
#   echo "### para $DIR ###"
#
#
# #----------------------------------------------------------
# # Configura archivo de control para  simulaciones de
# #  dispersion/concentracion
#
# iyr=19  # Anio solo los dos ultimos dígitos
# #ims=01  # Mes dos digitos
# idy=01  # Dia de inicio de modelacion
# ihr=06  # Hora de inicio de modelacion
#
# #  Ubicación de la fuente a modelar y altura
# lat=19.7208
# lon=-96.406
# lvl=100.0
# #
# vop=0         # Opcion de movimiento vertical
# run=12        # Numero de horas a modelar
# ztop=10000.0   # Altura del tope de modelacion
#
# nmf=1         # Numero de archivos meteorologicos
# MET="${HOME}/data/hysplit_data" # Directorio donde estan los data meteorologicos
# # para cada día
# for idy in 01 06 15 24
# do
# data="AR_${ims}${idy}20${iyr}.bin"  #nombre del archivo meteorologico
#
# #--------------------------------------------------------------
# #   Indica cada cuantas horas va a correr
# stph=01
# #   Indica el numero de dias a correr
# idia=00
# #   Indica el numero de horas despues de iniciar.
# hfin=30
#
# #--------------------------------------------------------------
# #  calcula las horas totales
# if [ $idia -lt 1 ] ; then
#    ht=$(($hfin+10#${ihr}))
#    else
#     ht=$((10#${ihr}+${idia}*24+10#${hfin}))
#    fi
# #
# # dias en el mes
# #    D   E  F  M  A  M  J  J  A  S  O  N  D
# mes=(31 31 28 31 30 31 30 31 31 30 31 30 31)
#
# #--------------------------------------------------------------
# # Datos de tiempo en loop
#
# for ih in $( seq $ihr $stph $ht )
# do
#  if [ $ih -gt 23 ] ; then
#    lh=$(($ih -24*$(($ih/24))))
#    ld=$((${idy}+ $ih/24 ))
#    if [ $ld -lt 10 ]; then ld=0$ld ;fi
#   else
#    lh=$ih
#    ld=$idy
#    lm=$ims
#  fi
#  if [ $ld -gt ${mes[$ims]} ]; then
#    lm=$(($ims + 1))
#    ld=$((${idy}+ $ih/24 - ${mes[$ims]}))
#    if [ $lm -lt 10 ]; then lm=0$lm ;fi
#    if [ $ld -lt 10 ]; then ld=0$ld ;fi
#  fi
# if [ $lh -lt 10 ]; then lh=0$lh ;fi
#
#
# # Creacion del archivo CONTROL
# #----------------------------------------------------------
# #
#
#   echo "$iyr $lm $ld $lh       " >CONTROL
#   echo "1                      ">>CONTROL
#   echo "$lat $lon $lvl         ">>CONTROL
#   echo "$run                   ">>CONTROL
#   echo "$vop                   ">>CONTROL
#   echo "$ztop                  ">>CONTROL
#   echo "$nmf                   ">>CONTROL
#   echo "$MET/                  ">>CONTROL
#   echo "$data                  ">>CONTROL
#   echo "$OUT/                  ">>CONTROL
#   echo "tdump$iyr$lm$ld$lh     ">>CONTROL
#
# #----------------------------------------------------------
# # corre la simulacion
#
#   rm -f SETUP.CFG
#
#   ${MDL}/exec/hyts_std >sal
#     echo "Terminado $iyr$lm$ld$lh"
# done # para cada hora
# done # para cada día
# done #para cada mes
# Out:
# ### para ene ###
# Terminado 19010106
# Terminado 19010107
# Terminado 19010108
# Terminado 19010109
# Terminado 19010110
# Terminado 19010111
# Terminado 19010112
# Terminado 19010113
# Terminado 19010114
# Terminado 19010115
# Terminado 19010116
# Terminado 19010117
# Terminado 19010118
# Terminado 19010119
# Terminado 19010120
# Terminado 19010121
# Terminado 19010122
# Terminado 19010123
# Terminado 19010200
# Terminado 19010201
# Terminado 19010202
# Terminado 19010203
# Terminado 19010204
# Terminado 19010205
# Terminado 19010206
# Terminado 19010207
# Terminado 19010208
# Terminado 19010209
# Terminado 19010210
# Terminado 19010211
# Terminado 19010212
# Terminado 19010606
# Terminado 19010607
# Terminado 19010608
# Terminado 19010609
# Terminado 19010610
# Terminado 19010611
# Terminado 19010612
# Terminado 19010613
# Terminado 19010614
# Terminado 19010615
# Terminado 19010616
# Terminado 19010617
# Terminado 19010618
# Terminado 19010619
# Terminado 19010620
# Terminado 19010621
# Terminado 19010622
# Terminado 19010623
# Terminado 19010700
# Terminado 19010701
# Terminado 19010702
# Terminado 19010703
# Terminado 19010704
# Terminado 19010705
# Terminado 19010706
# Terminado 19010707
# Terminado 19010708
# Terminado 19010709
# Terminado 19010710
# Terminado 19010711
# Terminado 19010712
# Terminado 19011506
# Terminado 19011507
# Terminado 19011508
# Terminado 19011509
# Terminado 19011510
# Terminado 19011511
# Terminado 19011512
# Terminado 19011513
# Terminado 19011514
# Terminado 19011515
# Terminado 19011516
# Terminado 19011517
# Terminado 19011518
# Terminado 19011519
# Terminado 19011520
# Terminado 19011521
# Terminado 19011522
# Terminado 19011523
# Terminado 19011600
# Terminado 19011601
# Terminado 19011602
# Terminado 19011603
# Terminado 19011604
# Terminado 19011605
# Terminado 19011606
# Terminado 19011607
# Terminado 19011608
# Terminado 19011609
# Terminado 19011610
# Terminado 19011611
# Terminado 19011612
# Terminado 19012406
<module>
# ----> 1 get_ipython().run_cell_magic('bash', '-l', '# para cada mes\ndeclare -a cmes=(ene feb mar abr may jun jul ago sep oct nov dic)\nfor i in ${!cmes[@]}\ndo\n# en la variable DIR definir el nombre del directorio\nDIR=${cmes[$i]}\nims=$(($i+1))\nif [ $ims -lt 10 ]; then ims=0$ims;fi\n# se revisa si existe en el directorio $HOME si no se crea\n\nif [ ! -d ${HOME}/data/$DIR ];then mkdir $HOME/data/$DIR ;fi\n\n# se ubica en el directorio\ncd ${HOME}/data/${DIR}\n#-------------------------------------------------------------\n# set default directory structure if not passed through\n\n  MDL="${HOME}/data/hysplit.v5.2.0_CentOS7.9.2009"\n  OUT="${HOME}/data/${DIR}"\n  MET="${HOME}/data/hysplit_data"\n  cd $OUT\n\n  if [ ! -f ASCDATA.CFG ]; then\n     echo "-90.0  -180.0"     >ASCDATA.CFG \n     echo "0.1     0.1"      >>ASCDATA.CFG\n     echo "1800   3600"      >>ASCDATA.CFG\n     echo "2"                >>ASCDATA.CFG\n     echo "0.2"              >>ASCDATA.CFG\n     echo "\'$MDL/bdyfiles/bdyfiles0p1/\'" >>ASCDATA.CFG\n  fi\n  echo "### para $DIR ###"\n\n\n#----------------------------------------------------------\n# Configura archivo de control para  simulaciones de \n#  dispersion/concentracion \n\niyr=19  # Anio solo los dos ultimos dígitos\n#ims=01  # Mes dos digitos\nidy=01  # Dia de inicio de modelacion\nihr=06  # Hora de inicio de modelacion\n\n#  Ubicación de la fuente a modelar y altura\nlat=19.7208   \nlon=-96.406\nlvl=100.0\n#  \nvop=0         # Opcion de movimiento vertical \nrun=12        # Numero de horas a modelar\nztop=10000.0   # Altura del tope de modelacion\n\nnmf=1         # Numero de archivos meteorologicos \nMET="${HOME}/data/hysplit_data" # Directorio donde estan los data meteorologicos\n# para cada día\nfor idy in 01 06 15 24\ndo\ndata="AR_${ims}${idy}20${iyr}.bin"  #nombre del archivo meteorologico\n\n#--------------------------------------------------------------\n#   Indica cada cuantas horas va a correr\nstph=01\n#   Indica el numero de dias a correr\nidia=00\n#   Indica el numero de horas despues de iniciar.\nhfin=30\n\n#--------------------------------------------------------------\n#  calcula las horas totales\nif [ $idia -lt 1 ] ; then\n   ht=$(($hfin+10#${ihr}))\n   else\n    ht=$((10#${ihr}+${idia}*24+10#${hfin}))\n   fi\n#\n# dias en el mes\n#    D   E  F  M  A  M  J  J  A  S  O  N  D          \nmes=(31 31 28 31 30 31 30 31 31 30 31 30 31)\n\n#--------------------------------------------------------------\n# Datos de tiempo en loop\n\nfor ih in $( seq $ihr $stph $ht )\ndo\n if [ $ih -gt 23 ] ; then\n   lh=$(($ih -24*$(($ih/24))))\n   ld=$((${idy}+ $ih/24 ))\n   if [ $ld -lt 10 ]; then ld=0$ld ;fi\n  else\n   lh=$ih\n   ld=$idy\n   lm=$ims\n fi\n if [ $ld -gt ${mes[$ims]} ]; then\n   lm=$(($ims + 1))\n   ld=$((${idy}+ $ih/24 - ${mes[$ims]}))\n   if [ $lm -lt 10 ]; then lm=0$lm ;fi\n   if [ $ld -lt 10 ]; then ld=0$ld ;fi\n fi\nif [ $lh -lt 10 ]; then lh=0$lh ;fi\n\n\n# Creacion del archivo CONTROL\n#----------------------------------------------------------\n# \n\n  echo "$iyr $lm $ld $lh       " >CONTROL\n  echo "1                      ">>CONTROL\n  echo "$lat $lon $lvl         ">>CONTROL\n  echo "$run                   ">>CONTROL\n  echo "$vop                   ">>CONTROL\n  echo "$ztop                  ">>CONTROL\n  echo "$nmf                   ">>CONTROL\n  echo "$MET/                  ">>CONTROL\n  echo "$data                  ">>CONTROL\n  echo "$OUT/                  ">>CONTROL\n  echo "tdump$iyr$lm$ld$lh     ">>CONTROL\n \n#----------------------------------------------------------\n# corre la simulacion\n\n  rm -f SETUP.CFG\n    \n  ${MDL}/exec/hyts_std >sal\n    echo "Terminado $iyr$lm$ld$lh"\ndone # para cada hora\ndone # para cada día\ndone #para cada mes\n')
#
# /opt/mambaforge/envs/Jupyter/lib/python3.10/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2417             with self.builtin_trap:
#    2418                 args = (magic_arg_s, cell)
# -> 2419                 result = fn(*args, **kwargs)
#    2420             return result
#    2421
#
# /opt/mambaforge/envs/Jupyter/lib/python3.10/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# /opt/mambaforge/envs/Jupyter/lib/python3.10/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# /opt/mambaforge/envs/Jupyter/lib/python3.10/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/mambaforge/envs/Jupyter/lib/python3.10/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'# para cada mes\ndeclare -a cmes=(ene feb mar abr may jun jul ago sep oct nov dic)\nfor i in ${!cmes[@]}\ndo\n# en la variable DIR definir el nombre del directorio\nDIR=${cmes[$i]}\nims=$(($i+1))\nif [ $ims -lt 10 ]; then ims=0$ims;fi\n# se revisa si existe en el directorio $HOME si no se crea\n\nif [ ! -d ${HOME}/data/$DIR ];then mkdir $HOME/data/$DIR ;fi\n\n# se ubica en el directorio\ncd ${HOME}/data/${DIR}\n#-------------------------------------------------------------\n# set default directory structure if not passed through\n\n  MDL="${HOME}/data/hysplit.v5.2.0_CentOS7.9.2009"\n  OUT="${HOME}/data/${DIR}"\n  MET="${HOME}/data/hysplit_data"\n  cd $OUT\n\n  if [ ! -f ASCDATA.CFG ]; then\n     echo "-90.0  -180.0"     >ASCDATA.CFG \n     echo "0.1     0.1"      >>ASCDATA.CFG\n     echo "1800   3600"      >>ASCDATA.CFG\n     echo "2"                >>ASCDATA.CFG\n     echo "0.2"              >>ASCDATA.CFG\n     echo "\'$MDL/bdyfiles/bdyfiles0p1/\'" >>ASCDATA.CFG\n  fi\n  echo "### para $DIR ###"\n\n\n#----------------------------------------------------------\n# Configura archivo de control para  simulaciones de \n#  dispersion/concentracion \n\niyr=19  # Anio solo los dos ultimos d\xc3\xadgitos\n#ims=01  # Mes dos digitos\nidy=01  # Dia de inicio de modelacion\nihr=06  # Hora de inicio de modelacion\n\n#  Ubicaci\xc3\xb3n de la fuente a modelar y altura\nlat=19.7208   \nlon=-96.406\nlvl=100.0\n#  \nvop=0         # Opcion de movimiento vertical \nrun=12        # Numero de horas a modelar\nztop=10000.0   # Altura del tope de modelacion\n\nnmf=1         # Numero de archivos meteorologicos \nMET="${HOME}/data/hysplit_data" # Directorio donde estan los data meteorologicos\n# para cada d\xc3\xada\nfor idy in 01 06 15 24\ndo\ndata="AR_${ims}${idy}20${iyr}.bin"  #nombre del archivo meteorologico\n\n#--------------------------------------------------------------\n#   Indica cada cuantas horas va a correr\nstph=01\n#   Indica el numero de dias a correr\nidia=00\n#   Indica el numero de horas despues de iniciar.\nhfin=30\n\n#--------------------------------------------------------------\n#  calcula las horas totales\nif [ $idia -lt 1 ] ; then\n   ht=$(($hfin+10#${ihr}))\n   else\n    ht=$((10#${ihr}+${idia}*24+10#${hfin}))\n   fi\n#\n# dias en el mes\n#    D   E  F  M  A  M  J  J  A  S  O  N  D          \nmes=(31 31 28 31 30 31 30 31 31 30 31 30 31)\n\n#--------------------------------------------------------------\n# Datos de tiempo en loop\n\nfor ih in $( seq $ihr $stph $ht )\ndo\n if [ $ih -gt 23 ] ; then\n   lh=$(($ih -24*$(($ih/24))))\n   ld=$((${idy}+ $ih/24 ))\n   if [ $ld -lt 10 ]; then ld=0$ld ;fi\n  else\n   lh=$ih\n   ld=$idy\n   lm=$ims\n fi\n if [ $ld -gt ${mes[$ims]} ]; then\n   lm=$(($ims + 1))\n   ld=$((${idy}+ $ih/24 - ${mes[$ims]}))\n   if [ $lm -lt 10 ]; then lm=0$lm ;fi\n   if [ $ld -lt 10 ]; then ld=0$ld ;fi\n fi\nif [ $lh -lt 10 ]; then lh=0$lh ;fi\n\n\n# Creacion del archivo CONTROL\n#----------------------------------------------------------\n# \n\n  echo "$iyr $lm $ld $lh       " >CONTROL\n  echo "1                      ">>CONTROL\n  echo "$lat $lon $lvl         ">>CONTROL\n  echo "$run                   ">>CONTROL\n  echo "$vop                   ">>CONTROL\n  echo "$ztop                  ">>CONTROL\n  echo "$nmf                   ">>CONTROL\n  echo "$MET/                  ">>CONTROL\n  echo "$data                  ">>CONTROL\n  echo "$OUT/                  ">>CONTROL\n  echo "tdump$iyr$lm$ld$lh     ">>CONTROL\n \n#----------------------------------------------------------\n# corre la simulacion\n\n  rm -f SETUP.CFG\n    \n  ${MDL}/exec/hyts_std >sal\n    echo "Terminado $iyr$lm$ld$lh"\ndone # para cada hora\ndone # para cada d\xc3\xada\ndone #para cada mes\n'' returned non-zero exit status 1.

# %%
# %%bash -l
#
# ls  ../data/ene/tdump* |wc -l
# tail -1 ../data/ene/tdump19012512
# cat ../data/ene/tdump19012512

# %% [markdown]
# ## Visualización de las trayectorias

# %%
# %%bash -l
# # en la variable DIR definir el nombre del directorio
# DIR=enero
# MDL="${HOME}/data/hysplit.v5.2.0_CentOS7.9.2009"
#
#
# # se revisa si existe en el directorio $HOME si no se crea
#
# if [ ! -d ${HOME}/data/$DIR ];then mkdir $HOME/data/$DIR ;fi
#
# # se ubica en el directorio
# cd ${HOME}/data/${DIR}
# # Genera el archivo de todas las trayectorias
# #ls -r tdump1901011* > INFILE
# ls tdump1901*  > INFILE
#
#  WEB=""
#   if [ -f /bin/convert ];then WEB="/bin/convert";fi
#
# echo "'$MDL/graphics/mexico.shp' 0 0.01 0.4 0.6 0.8" >shapefiles_mex.txt
#
# #-------------------------------------------------------------
# # set default directory structure if not passed through
#
#
# echo "'TITLE&','Trayectorias de Enero 01 06 &'"  >LABELS.CFG
# ${MDL}/exec/trajplot  +g0 -i+INFILE -jshapefiles_mex.txt -l3 -v3 -otray.ps -z0 -h19.7:-96.4
#
# ${WEB} tray.ps tray.jpg
